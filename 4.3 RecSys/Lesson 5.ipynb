# %% [markdown]
# #### Ответьте на вопросы:
# #### - В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной филтьтрации?

# %% [markdown]
# В коллаборативной фильтрации используются только матрицы интеракций, рекомендации строятся на основе похожих пользователей.
# В гибридных системах к матрице интеракций добавляются внешние признаки, что в комбинации улучшает рекомендацию

# %% [markdown]
# #### Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы
#
# 1. Применяется в онлайн-магазинах
# 2. Онлайн-кинотеатры
# 3. Лента новостей в соцсети
#
# все они строят рекомендации на основе истории пользователя в комбинации с похожими пользователями

# %% [markdown]
# #### - Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/ Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# Используют две модели - одну линейную, чтобы отсечь все лишнее, а затем XGBoost для ранжирования. XGboost вступает, после того, как уже отфильтрованы вручную и программными методами значительная часть признаков.
# И на этапе ранжирования алгоритм приоритезирует рекламные вакансии, что помогает монетизировать бизнес компании

# %% [markdown]
# #### - На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
#
# 1) Какой датасет используют авторы?

# %% [markdown]
# 1. MovieLens 10M, объединенный с the Tag Genome
# 2. CrossValidated

# %% [markdown]
# #### 2) Что используют в качестве признаков?

# %% [markdown]
# 1. Каждому фильму относится список жанров и список тэгов. У каждого тэга стоит рейтинг точности от 0 до 1, описывающий, как точно тэг подходит фильму. Также у каждого фильма стоит рейтинг из оценок всех пользователей.
# 2. вопросы и ответы пользователей

# %% [markdown]
# #### 3) С какими моделями сравнивают LightFM? Опишите их основные идеи кратко

# %% [markdown]
# * MF - матричная модель User х Item с функцией сигмойды
# * LSI-LR - логистическая регрессияю. Основывается на факторизации матрицы контента.
# * LSI-UP - гибридная модель, которая представляет профили пользователей, как линейную комбинацию предметов по векторам, затем применяет LSI к получившейся матрице, чтобы получить скрытые представления пользователей и элементов.
