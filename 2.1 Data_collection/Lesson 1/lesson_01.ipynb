# %% [markdown]
# ### Урок 1. Основы клиент-серверного взаимодействия. Парсинг API

# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
import json

# %%
main_link = 'https://api.github.com/'
user='Kaldun73'

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36 OPR/67.0.3575.115'}

# %%
params = {'user':user,
         'per_page':10000}
response = requests.get(main_link,headers=headers,params=params)

# %%
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
for i in r.json():
    print(i['name'])
# Out:
# HomeTask
# pythonDS
# realestatepriceprediction

# %% [markdown]
# 2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
main_link_2 = 'https://api.vk.com/method/video.get?v=5.52'
token='4c11c4d6dc44bec2a238f60d74d302e25d9a87d2f1857200cb627507fb85d8bba068c87b259b83b1175c2'

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36 OPR/67.0.3575.115'}

# %%
params = {'access_token': token}

# %%
vk = requests.get(f'{main_link_2}', headers=headers, params=params)
vk.json()
# Out:
# {'response': {'count': 137,
#   'items': [{'adding_date': 1471280583,
#     'can_comment': 1,
#     'can_like': 1,
#     'can_repost': 1,
#     'can_subscribe': 1,
#     'can_add_to_faves': 1,
#     'can_add': 1,
#     'comments': 0,
#     'date': 1454343695,
#     'description': 'International sensation LET IT BE is now playing at London’s Garrick Theatre! Seen by over 1 million people worldwide, LET IT BE is jam-packed with over forty of The Beatles’ greatest hits. For more information and tickets click Tickets Relive The Beatles’ meteoric rise from their humble beginnings in Liverpool’s Cavern Club, through the heights of Beatlemania, to their later studio masterpieces, with live performances of early tracks including Twist and Shout, She Loves You and Drive My Car, as well as glo',
#     'duration': 7842,
#     'photo_130': 'https://sun9-52.userapi.com/c630529/u164669309/video/s_81d476ce.jpg',
# ...

# %%
for i in vk.json()['response']['items']:
    print(i['title'])
# Out:
# Let It Be Musical - Garrick Theatre, London  2/9/16
# Beatlove 16.01.16
# Blue October - Things We Do At Night (Live From Texas 2015)
# Южный парк 0 сезон 2 серия Дух Рождества (Иисус против Санты) 1995год
# Морозова стебанул Фрай
# Кукла «Я покакала! Фууу!»
# Blue October - She's My Ride Home
# Blue October - Not Broken Anymore (live in Moscow)
# Blue October - Hate Me (live in Moscow)
# Blue October - Bleed Out (live in Moscow)
# Blue October - Should Be Loved (live in Moscow)
# Blue October - Dirt Room (live in Moscow)
# Blue October - Say It (live in Moscow)
# Blue October - Sway (live in Moscow)
# Foals Glastonbury 2013
# Hurts at Glastonbury 2013 (Full show live)
# Arctic Monkeys | Glastonbury 2013
# Космическая станция 3D (2002)
# Queen: Hungarian Rhapsody - Live In Budapest (1986/2012) / Blu-ray / Лицензия
# Kasabian "Video Games" Lana Del Rey Cover
# Golden Loves Guitar !!
# E o Pintinho piu no RATINHO
# Kasabian - Acoustic Live At The Bus Palladium
# ...

# %%
with open('vk.json', 'w') as f:
    json.dump(vk.json(), f)
