# %%
from pprint import pprint
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd
from pymongo import MongoClient
import json
import itertools
import datetime

# %%
def hh():
    main_link = 'https://hh.ru'
    vacancy_name = input("Введите название вакансии: ").split(' ')
    vacancy_name = "+".join(vacancy_name)

    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}
    # params = {'items_on_page': '100'}
    response = requests.get(main_link + '/search/vacancy?area=&st=searchVacancy&text=' + vacancy_name, headers=headers).text
    soup = bs(response, 'lxml')

    vacancies = []

    next_button = soup.find('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})
    range_len = int(next_button.find_previous_sibling().findChild('a', {'class': 'bloko-button HH-Pager-Control'}).getText())

    for i in range(0, range_len-1):
        vacancy_block = soup.find('div',{'class':'vacancy-serp'})
        vacancy_list = vacancy_block.findChildren('div',{'class':'vacancy-serp-item'}, recursive=False)

        for vacancy in vacancy_list:
            vacancy_data={}
            request = vacancy.find('span', {'class':'g-user-content'})
            if request != None:
                main_data = request.findChild()
                vacancy_name = main_data.getText()
                vacancy_data['vacancy_name'] = vacancy_name

                vacancy_link = main_data['href']
                vacancy_data['vacancy_link'] = vacancy_link
                
                vacancy_data['vacancy_id'] = int(re.search(r'\d+', vacancy_link).group(0))

                company_name = vacancy.find('div', {'class': 'vacancy-serp-item__meta-info'}).getText()
                vacancy_data['company_name'] = company_name
                
                vacancy_city = vacancy.find('span', {'data-qa':'vacancy-serp__vacancy-address'}).getText().split(' ')
                vacancy_data['vacancy_city'] = vacancy_city[0]

                vacancy_wage = vacancy.find('div', {'class':'vacancy-serp-item__sidebar'}).getText().replace(u'\xa0', u'')

                vacancy_wage = re.split(r'\s|-', vacancy_wage)

                if vacancy_wage[0] == 'до':
                    wage_min = None
                    wage_max = int(vacancy_wage[1])
                    wage_currency = vacancy_wage[2]
                elif vacancy_wage[0] == 'от':
                    wage_min = int(vacancy_wage[1])
                    wage_max = None
                    wage_currency = vacancy_wage[2]
                elif vacancy_wage[0] == '':
                    wage_min = None
                    wage_max = None
                    wage_currency = None
                else:
                    wage_min = int(vacancy_wage[0])
                    wage_max = int(vacancy_wage[1])
                    wage_currency = vacancy_wage[2]

                vacancy_data['wage_min'] = wage_min
                vacancy_data['wage_max'] = wage_max
                vacancy_data['wage_currency'] = wage_currency

                vacancy_data['vacancy_source'] = 'hh.ru'

            vacancies.append(vacancy_data)


        next_page_block = soup.find('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})
        if next_page_block is False:
            break
        else:
            next_page_link = next_page_block['href']
            response = requests.get(main_link + next_page_link, headers=headers).text
            soup = bs(response, 'lxml')

    

    df_hh = pd.DataFrame(vacancies)
    return df_hh

# %%
def superjob():
    main_link = 'https://russia.superjob.ru'
    vacancy_name = input("Введите название вакансии: ").split(' ')
    vacancy_name = "-".join(vacancy_name)

    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}
    response = requests.get(main_link + '/vacancy/search/?keywords=' + vacancy_name, headers=headers).text
    soup = bs(response, 'lxml')

    vacancies = []

    next_button = soup.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-Dalshe'})
    range_len = int(next_button.previous_element)

    for i in range(range_len-1):
        vacancy_block = soup.find('div', {'style': 'display:block'})
        vacancy_list = vacancy_block.find_all('div', {'class': 'iJCa5 _2gFpt _1znz6 _2nteL'}, recursive=False)

        for vacancy in vacancy_list:
            vacancy_data = {}
            request = vacancy.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'})
            if request != None:
                main_data = request.findChild()
                vacancy_name = main_data.getText()
                vacancy_data['vacancy_name'] = vacancy_name

                vacancy_link = main_data['href']
                vacancy_data['vacancy_link'] = main_link + vacancy_link
                
                vacancy_data['vacancy_id'] = int(re.search(r'\d+', vacancy_link).group(0))

                company_name = vacancy.find('a', {'target': '_self'}).getText()
                vacancy_data['company_name'] = company_name

                vacancy_city = vacancy.find('span', {
                    'class': '_3mfro f-test-text-company-item-location _9fXTd _2JVkc _2VHxz'}).getText().split(' ')
                vacancy_data['vacancy_city'] = vacancy_city[2]

                vacancy_wage = vacancy.find('span', {'class':'_3mfro _2Wp8I _31tpt f-test-text-company-item-salary PlM3e _2JVkc _2VHxz'}).getText().replace(u'\xa0', u' ')
                vacancy_wage = re.split(r'\s|-', vacancy_wage)

                if vacancy_wage[-1] != 'договорённости':
                    wage_currency = vacancy_wage[-1]
                else: wage_currency = None

                if vacancy_wage[0] == 'до':
                    wage_min = None
                    wage_max = int(vacancy_wage[1]+vacancy_wage[2])
                elif vacancy_wage[0] == 'от':
                    wage_min = int(vacancy_wage[1]+vacancy_wage[2])
                    wage_max = None
                elif vacancy_wage[0] == 'По':
                    wage_min = None
                    wage_max = None
                elif vacancy_wage[2] == '—':
                    wage_min = int(vacancy_wage[0]+vacancy_wage[1])
                    wage_max = int(vacancy_wage[3]+vacancy_wage[4])

                vacancy_data['wage_min'] = wage_min
                vacancy_data['wage_max'] = wage_max
                vacancy_data['wage_currency'] = wage_currency

                vacancy_data['vacancy_source'] = 'superjob.ru'

            vacancies.append(vacancy_data)

        next_page_link = soup.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-Dalshe'})['href']
        response = requests.get(main_link + next_page_link, headers=headers).text
        soup = bs(response, 'lxml')

    df_sj = pd.DataFrame(vacancies)
    return df_sj

# %%
df = pd.concat([hh(),superjob()], ignore_index=True)
# Out:
# Введите название вакансии: python
# Введите название вакансии: python

# %% [markdown]
# ## 1) Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД

# %%
with open('df.json', 'w', encoding='utf-8') as file:
    df.to_json(r'C:\Users\vladi\Desktop\Data_collection\vacancies.json')

# %%
client = MongoClient( 'localhost' , 27017 )
db = client['vacancybase']
collection = db.vacancybase

# %%
df = pd.read_json(r'C:\Users\vladi\Desktop\Data_collection\vacancies.json', orient="columns")
df.head(3)
# Out:
#                 vacancy_name                                 vacancy_link  \
# 0           Python Developer  https://hh.ru/vacancy/35095020?query=python
# 1            Веб-разработчик  https://hh.ru/vacancy/36667521?query=python
# 2  Researcher/Data Scientist  https://hh.ru/vacancy/36659106?query=python
#
#    vacancy_id                                     company_name vacancy_city  \
# 0    35095020                                 УП Руна Системс        Минск,
# 1    36667521                                        Datafold           США
# 2    36659106  ООО СК хайникс мемори солюшнс Восточная Европа        Минск,
#
#    wage_min  wage_max wage_currency vacancy_source
# 0    2500.0       NaN           USD          hh.ru
# 1    2000.0       NaN           USD          hh.ru
# 2       NaN       NaN          None          hh.ru

# %%
df_dict = df.to_dict(orient= 'index')
dict(itertools.islice(df_dict.items(), 3))
# Out:
# {0: {'vacancy_name': 'Python Developer',
#   'vacancy_link': 'https://hh.ru/vacancy/35095020?query=python',
#   'vacancy_id': 35095020,
#   'company_name': 'УП Руна Системс\xa0',
#   'vacancy_city': 'Минск,',
#   'wage_min': 2500.0,
#   'wage_max': nan,
#   'wage_currency': 'USD',
#   'vacancy_source': 'hh.ru'},
#  1: {'vacancy_name': 'Веб-разработчик',
#   'vacancy_link': 'https://hh.ru/vacancy/36667521?query=python',
#   'vacancy_id': 36667521,
#   'company_name': ' Datafold\xa0',
#   'vacancy_city': 'США',
#   'wage_min': 2000.0,
#   'wage_max': nan,
#   'wage_currency': 'USD',
#   'vacancy_source': 'hh.ru'},
#  2: {'vacancy_name': 'Researcher/Data Scientist',
#   'vacancy_link': 'https://hh.ru/vacancy/36659106?query=python',
#   'vacancy_id': 36659106,
#   'company_name': 'ООО СК хайникс мемори солюшнс Восточная Европа\xa0',
#   'vacancy_city': 'Минск,',
#   'wage_min': nan,
#   'wage_max': nan,
#   'wage_currency': None,
#   'vacancy_source': 'hh.ru'}}

# %%
df_list = [*df_dict.values()]

# %%
collection.insert_many(df_list)

# %% [markdown]
# ## 2) Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы

# %%
wage = 2000 
result = collection.find({'$and': [{'wage_min':{'$gt' : wage}}, {'wage_currency':{'$eq' : 'USD'}}]}).sort('wage_min', -1)
df = pd.DataFrame.from_dict(result)

df
# Out:
#                          _id  \
# 0   5e9b53e835bbbcef04e20f08
# 1   5e9b53e835bbbcef04e21057
# 2   5e9b53e835bbbcef04e21369
# 3   5e9b53e835bbbcef04e213a8
# 4   5e9b53e835bbbcef04e21671
# 5   5e9b5489ba68f82798d8d25f
# 6   5e9b5489ba68f82798d8d3ae
# 7   5e9b5489ba68f82798d8d6bf
# 8   5e9b5489ba68f82798d8d6ff
# 9   5e9b5489ba68f82798d8d9c7
# 10  5e9b565f9b3d9b2c2ea6cbaa
# 11  5e9b565f9b3d9b2c2ea6ccf9
# 12  5e9b565f9b3d9b2c2ea6d00a
# 13  5e9b565f9b3d9b2c2ea6d049
# 14  5e9b565f9b3d9b2c2ea6d312
# 15  5e9b53e835bbbcef04e212dd
# 16  5e9b53e835bbbcef04e213f5
# 17  5e9b53e835bbbcef04e2146f
# 18  5e9b5489ba68f82798d8d633
# 19  5e9b5489ba68f82798d8d74b
# 20  5e9b5489ba68f82798d8d7c5
# 21  5e9b565f9b3d9b2c2ea6cf7e
# 22  5e9b565f9b3d9b2c2ea6d096
# 23  5e9b565f9b3d9b2c2ea6d110
# 24  5e9b53e835bbbcef04e20ee5
# 25  5e9b53e835bbbcef04e2110c
# 26  5e9b53e835bbbcef04e21218
# 27  5e9b53e835bbbcef04e2145c
# 28  5e9b5489ba68f82798d8d23c
# 29  5e9b5489ba68f82798d8d464
# 30  5e9b5489ba68f82798d8d56e
# 31  5e9b5489ba68f82798d8d7b2
# 32  5e9b565f9b3d9b2c2ea6cb87
# 33  5e9b565f9b3d9b2c2ea6cdaf
# 34  5e9b565f9b3d9b2c2ea6ceb9
# 35  5e9b565f9b3d9b2c2ea6d0fd
# 36  5e9b53e835bbbcef04e20ed8
# 37  5e9b53e835bbbcef04e20eed
# 38  5e9b53e835bbbcef04e212c0
# 39  5e9b5489ba68f82798d8d22e
# 40  5e9b5489ba68f82798d8d243
# 41  5e9b5489ba68f82798d8d616
# 42  5e9b565f9b3d9b2c2ea6cb79
# 43  5e9b565f9b3d9b2c2ea6cb8e
# 44  5e9b565f9b3d9b2c2ea6cf61
# 45  5e9b53e835bbbcef04e212e5
# 46  5e9b5489ba68f82798d8d63b
# 47  5e9b565f9b3d9b2c2ea6cf86
#
#                                          vacancy_name  \
# 0                             Senior Python developer
# 1                       Software Engineer (С++/CMake)
# 2                                         CI Engineer
# 3   Технический руководитель разработки автоматиче...
# 4                             Blockchain Engineer R&D
# 5                             Senior Python developer
# 6                       Software Engineer (С++/CMake)
# 7                                         CI Engineer
# 8   Технический руководитель разработки автоматиче...
# 9                             Blockchain Engineer R&D
# 10                            Senior Python developer
# 11                      Software Engineer (С++/CMake)
# 12                                        CI Engineer
# 13  Технический руководитель разработки автоматиче...
# 14                            Blockchain Engineer R&D
# 15            Senior Software Engineer Embedded C/C++
# 16                              Python/Java developer
# 17                   Senior dev in intuition machines
# 18            Senior Software Engineer Embedded C/C++
# 19                              Python/Java developer
# 20                   Senior dev in intuition machines
# 21            Senior Software Engineer Embedded C/C++
# 22                              Python/Java developer
# 23                   Senior dev in intuition machines
# 24                    QA Automation Engineer (Python)
# 25                   Senior Machine Learning Engineer
# 26                          Machine Learning Engineer
# 27               Technical Support Engineer (Nx Meta)
# 28                    QA Automation Engineer (Python)
# 29                   Senior Machine Learning Engineer
# 30                          Machine Learning Engineer
# 31               Technical Support Engineer (Nx Meta)
# 32                    QA Automation Engineer (Python)
# 33                   Senior Machine Learning Engineer
# 34                          Machine Learning Engineer
# 35               Technical Support Engineer (Nx Meta)
# 36                                   Python Developer
# 37                            Senior Python developer
# 38                                   Python Developer
# 39                                   Python Developer
# 40                            Senior Python developer
# 41                                   Python Developer
# 42                                   Python Developer
# 43                            Senior Python developer
# 44                                   Python Developer
# 45                 Salesforce Developer Middle/Senior
# 46                 Salesforce Developer Middle/Senior
# 47                 Salesforce Developer Middle/Senior
#
#                                    vacancy_link  vacancy_id  \
# 0   https://hh.ru/vacancy/30005963?query=python    30005963
# 1   https://hh.ru/vacancy/29056936?query=python    29056936
# 2   https://hh.ru/vacancy/27812469?query=python    27812469
# 3   https://hh.ru/vacancy/35944842?query=python    35944842
# 4   https://hh.ru/vacancy/35358182?query=python    35358182
# 5   https://hh.ru/vacancy/30005963?query=python    30005963
# 6   https://hh.ru/vacancy/29056936?query=python    29056936
# 7   https://hh.ru/vacancy/27812469?query=python    27812469
# 8   https://hh.ru/vacancy/35944842?query=python    35944842
# 9   https://hh.ru/vacancy/35358182?query=python    35358182
# 10  https://hh.ru/vacancy/30005963?query=python    30005963
# 11  https://hh.ru/vacancy/29056936?query=python    29056936
# 12  https://hh.ru/vacancy/27812469?query=python    27812469
# 13  https://hh.ru/vacancy/35944842?query=python    35944842
# 14  https://hh.ru/vacancy/35358182?query=python    35358182
# 15  https://hh.ru/vacancy/36378820?query=python    36378820
# 16  https://hh.ru/vacancy/36465469?query=python    36465469
# 17  https://hh.ru/vacancy/36690804?query=python    36690804
# 18  https://hh.ru/vacancy/36378820?query=python    36378820
# 19  https://hh.ru/vacancy/36465469?query=python    36465469
# 20  https://hh.ru/vacancy/36690804?query=python    36690804
# 21  https://hh.ru/vacancy/36378820?query=python    36378820
# 22  https://hh.ru/vacancy/36465469?query=python    36465469
# 23  https://hh.ru/vacancy/36690804?query=python    36690804
# 24  https://hh.ru/vacancy/35419959?query=python    35419959
# 25  https://hh.ru/vacancy/36597566?query=python    36597566
# 26  https://hh.ru/vacancy/36353896?query=python    36353896
# 27  https://hh.ru/vacancy/35594122?query=python    35594122
# 28  https://hh.ru/vacancy/35419959?query=python    35419959
# 29  https://hh.ru/vacancy/36597566?query=python    36597566
# 30  https://hh.ru/vacancy/36353896?query=python    36353896
# 31  https://hh.ru/vacancy/35594122?query=python    35594122
# 32  https://hh.ru/vacancy/35419959?query=python    35419959
# 33  https://hh.ru/vacancy/36597566?query=python    36597566
# 34  https://hh.ru/vacancy/36353896?query=python    36353896
# 35  https://hh.ru/vacancy/35594122?query=python    35594122
# 36  https://hh.ru/vacancy/35095020?query=python    35095020
# 37  https://hh.ru/vacancy/36435018?query=python    36435018
# 38  https://hh.ru/vacancy/36530566?query=python    36530566
# 39  https://hh.ru/vacancy/35095020?query=python    35095020
# 40  https://hh.ru/vacancy/36435018?query=python    36435018
# 41  https://hh.ru/vacancy/36530566?query=python    36530566
# 42  https://hh.ru/vacancy/35095020?query=python    35095020
# 43  https://hh.ru/vacancy/36435018?query=python    36435018
# 44  https://hh.ru/vacancy/36530566?query=python    36530566
# 45  https://hh.ru/vacancy/36691213?query=python    36691213
# 46  https://hh.ru/vacancy/36691213?query=python    36691213
# 47  https://hh.ru/vacancy/36691213?query=python    36691213
#
#                   company_name      vacancy_city  wage_min  wage_max  \
# 0                NetworkOptix            Москва,    4000.0       NaN
# 1                NetworkOptix            Москва,    4000.0       NaN
# 2                NetworkOptix            Москва,    4000.0       NaN
# 3                NetworkOptix             Москва    4000.0       NaN
# 4                     LATOKEN             Москва    4000.0    6000.0
# 5                NetworkOptix            Москва,    4000.0       NaN
# 6                NetworkOptix            Москва,    4000.0       NaN
# 7                NetworkOptix            Москва,    4000.0       NaN
# 8                NetworkOptix             Москва    4000.0       NaN
# 9                     LATOKEN             Москва    4000.0    6000.0
# 10               NetworkOptix            Москва,    4000.0       NaN
# 11               NetworkOptix            Москва,    4000.0       NaN
# 12               NetworkOptix            Москва,    4000.0       NaN
# 13               NetworkOptix             Москва    4000.0       NaN
# 14                    LATOKEN             Москва    4000.0    6000.0
# 15      ООО ФЛП Воронова И.Н.              Львов    3500.0    5000.0
# 16                   Tango Me   Санкт-Петербург,    3500.0    4000.0
# 17   Новикова Анна Анатольевна             Минск    3500.0    5000.0
# 18      ООО ФЛП Воронова И.Н.              Львов    3500.0    5000.0
# 19                   Tango Me   Санкт-Петербург,    3500.0    4000.0
# 20   Новикова Анна Анатольевна             Минск    3500.0    5000.0
# 21      ООО ФЛП Воронова И.Н.              Львов    3500.0    5000.0
# 22                   Tango Me   Санкт-Петербург,    3500.0    4000.0
# 23   Новикова Анна Анатольевна             Минск    3500.0    5000.0
# 24               NetworkOptix            Москва,    3000.0       NaN
# 25               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 26               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 27               NetworkOptix             Москва    3000.0       NaN
# 28               NetworkOptix            Москва,    3000.0       NaN
# 29               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 30               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 31               NetworkOptix             Москва    3000.0       NaN
# 32               NetworkOptix            Москва,    3000.0       NaN
# 33               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 34               ООО HR-PROFI    Санкт-Петербург    3000.0    6000.0
# 35               NetworkOptix             Москва    3000.0       NaN
# 36            УП Руна Системс             Минск,    2500.0       NaN
# 37               Openprovider        Новосибирск    2500.0       NaN
# 38                  ООО Бонер             Минск,    2500.0    4500.0
# 39            УП Руна Системс             Минск,    2500.0       NaN
# 40               Openprovider        Новосибирск    2500.0       NaN
# 41                  ООО Бонер             Минск,    2500.0    4500.0
# 42            УП Руна Системс             Минск,    2500.0       NaN
# 43               Openprovider        Новосибирск    2500.0       NaN
# 44                  ООО Бонер             Минск,    2500.0    4500.0
# 45             ООО Джет Би Ай             Минск,    2200.0       NaN
# 46             ООО Джет Би Ай             Минск,    2200.0       NaN
# 47             ООО Джет Би Ай             Минск,    2200.0       NaN
#
#    wage_currency vacancy_source
# 0            USD          hh.ru
# 1            USD          hh.ru
# 2            USD          hh.ru
# 3            USD          hh.ru
# 4            USD          hh.ru
# 5            USD          hh.ru
# 6            USD          hh.ru
# 7            USD          hh.ru
# 8            USD          hh.ru
# 9            USD          hh.ru
# 10           USD          hh.ru
# 11           USD          hh.ru
# 12           USD          hh.ru
# 13           USD          hh.ru
# 14           USD          hh.ru
# 15           USD          hh.ru
# 16           USD          hh.ru
# 17           USD          hh.ru
# 18           USD          hh.ru
# 19           USD          hh.ru
# 20           USD          hh.ru
# 21           USD          hh.ru
# 22           USD          hh.ru
# 23           USD          hh.ru
# 24           USD          hh.ru
# 25           USD          hh.ru
# 26           USD          hh.ru
# 27           USD          hh.ru
# 28           USD          hh.ru
# 29           USD          hh.ru
# 30           USD          hh.ru
# 31           USD          hh.ru
# 32           USD          hh.ru
# 33           USD          hh.ru
# 34           USD          hh.ru
# 35           USD          hh.ru
# 36           USD          hh.ru
# 37           USD          hh.ru
# 38           USD          hh.ru
# 39           USD          hh.ru
# 40           USD          hh.ru
# 41           USD          hh.ru
# 42           USD          hh.ru
# 43           USD          hh.ru
# 44           USD          hh.ru
# 45           USD          hh.ru
# 46           USD          hh.ru
# 47           USD          hh.ru

# %%
for i in df_list:
        collection.update_one({'vacancy_id': i['vacancy_id']}, {'$set': {'vacancy_name': i['vacancy_name'], 'vacancy_link': i['vacancy_link'], 'vacancy_id': i['vacancy_id'], 'company_name': i['company_name'], 'vacancy_city': i['vacancy_city'], 'wage_min': i['wage_min'], 'wage_max': i['wage_max'], 'wage_currency': i['wage_currency'], 'vacancy_source': i['vacancy_source']}}, upsert=True)
pd.DataFrame(list(collection.find({}, {'_id': 0})))
# Out:
#                                            vacancy_link  \
# 0           https://hh.ru/vacancy/35095020?query=python
# 1           https://hh.ru/vacancy/36667521?query=python
# 2           https://hh.ru/vacancy/36659106?query=python
# 3           https://hh.ru/vacancy/36437342?query=python
# 4           https://hh.ru/vacancy/36631687?query=python
# ...                                                 ...
# 1982  https://russia.superjob.ru/vakansii/analitik-3...
# 1983  https://russia.superjob.ru/vakansii/docent-335...
# 1984  https://russia.superjob.ru/vakansii/analitik-3...
# 1985  https://russia.superjob.ru/vakansii/programmis...
# 1986  https://russia.superjob.ru/vakansii/bioinforma...
#
#                                          company_name vacancy_city  \
# 0                                    УП Руна Системс        Минск,
# 1                                           Datafold           США
# 2     ООО СК хайникс мемори солюшнс Восточная Европа        Минск,
# 3                                            ДомКлик   Новосибирск
# 4                                       ООО Центр 2М        Москва
# ...                                               ...          ...
# 1982                                      Ипатюк Олег            •
# 1983                    Южный федеральный университет            •
# 1984                                    РЕСО-Гарантия            •
# 1985  Центр стратегического планирования Минздрава РФ            •
# 1986  Центр стратегического планирования Минздрава РФ            •
#
#       vacancy_id                      vacancy_name vacancy_source  \
# 0       35095020                  Python Developer          hh.ru
# 1       36667521                   Веб-разработчик          hh.ru
# 2       36659106         Researcher/Data Scientist          hh.ru
# 3       36437342               Администратор Linux          hh.ru
# 4       36631687      Golang разработчик (Backend)          hh.ru
# ...          ...                               ...            ...
# 1982    33738136                          Аналитик    superjob.ru
# 1983    33560652                            Доцент    superjob.ru
# 1984    31183225                          Аналитик    superjob.ru
# 1985    33437653                       Программист    superjob.ru
# 1986    33684814  Биоинформатик, научный сотрудник    superjob.ru
#
#      wage_currency  wage_max  wage_min
# 0              USD       NaN    2500.0
# 1              USD       NaN    2000.0
# 2             None       NaN       NaN
# 3             None       NaN       NaN
# 4             руб.  250000.0  230000.0
# ...            ...       ...       ...
# 1982          руб.       NaN   50000.0
# 1983          руб.       NaN   40000.0
# 1984          None       NaN       NaN
# 1985          руб.       NaN  150000.0
# 1986          None       NaN       NaN
#
# [1987 rows x 9 columns]
